# %%
# Import
import itertools
import json

import numpy as np
import random
from munkres import Munkres
import time
from pymoo.indicators.hv import HV

# %%
def get_sols(r):
    n=int(r.readline())
    for _ in range(n):
        sols.append(list(map(int, r.readline().split()))[1:])
    return sols

def load_datas(filename: object, N_obj: object, get_sol=True) -> object:
    objectifs = []
    with open(filename, 'r') as r:
        dim = int(r.readline())
        for _ in range(4):
            tmp = [list(map(int, r.readline().split())) for _ in range(dim)]
            objectifs.append(np.array(tmp))

        sols=[]
        if get_sol:
            sols = get_sols(r)
    return objectifs[:N_obj], dim, sols

# %%
def create_mat(positions, N):
    vals = []
    tmp = np.zeros((N, N))
    for index in positions:
        tmp[index[0]][index[1]] = 1
    vals.append(tmp)
    return vals

# %%
def fast_compute_objectifs(coordinates, objectifs):
    return [int(sum([objectif[x, y] for x, y in coordinates])) for objectif in objectifs]

# %%
def sol_is_valid(coordinates):
    rows = set([x for x, y in coordinates])
    columns = set([y for x, y in coordinates])
    if len(rows) == len(coordinates) and len(columns) == len(coordinates):
        # print("Il n'y a pas de doublons.")
        return True
    else:
        # print("Il y a des doublons.")
        return False

# %%
def generate_identity_and_reverse(dim):
    identi = np.identity(dim)
    indices = np.nonzero(identi)
    start = list(zip(indices[0], indices[1]))
    flip_start = np.fliplr(identi)
    indices = np.nonzero(flip_start)
    flip_start = list(zip(indices[0], indices[1]))
    return [start, flip_start]

# %%
def generate_best_single_obj(objectifs):
    vals = []
    objs_copy = np.copy(objectifs)
    for i in range(len(objectifs)):
        m = Munkres()
        indexes = m.compute(objs_copy[i])
        vals.append(indexes)
    return vals

# %%
def write_solutions(lap, filename, A):
    with open(f'solutions_multi/lap-{lap}/{filename}.txt', 'w') as w:
        w.write(f'{len(A)}\n')
        for a in A:
            w.write(' '.join(str(p) for p in a[0]))
            w.write('\n')

    ##########################################################

    with open(f'solutions_pts_multi/lap-{lap}/{filename}.txt', 'w') as w:
        w.write(f'{len(A)}\n')
        for a in A:
            w.write('   '.join(str(p) for p in a[1]))
            w.write('\n')

# %%
def make_n_permute(tuple_list, n):
    coordinates = tuple_list.copy()
    samples = random.sample(coordinates, n)
    l1, l2 = zip(*samples)
    line_permute = [(x, y) for x, y in zip(random.sample(l1, len(l1)), l2)]
    for sample in samples:
        coordinates.remove(sample)
    return coordinates + line_permute

# %%
import itertools
def permute_all_possibility(tuple_list):
    l1, l2 = zip(*tuple_list)
    possibilities = list(itertools.permutations(l2))
    pts = []
    for p in possibilities:
        pts.append(list(zip(l1, p)))
    return pts

# %%
def fast_random_permute(tuple_list, N, exclusions):
    voisins = []
    for i in range(N):
        x, y = zip(*tuple_list)
        random.shuffle(list(y))
        l1 = list(zip(x, y))
        l1.sort()
        if sol_is_valid(l1) and str(l1) not in exclusions:
            voisins.append(l1)
            exclusions.add(str(l1))

        for it in [2, 2, 3,  5, 10, 15]:
            l2 = make_n_permute(tuple_list, it)
            l2.sort()
            if sol_is_valid(l2) and str(l2) not in exclusions:
                voisins.append(l2)
                exclusions.add(str(l2))
        # l2 = make_n_permute(tuple_list, 5)
        # l2.sort()
        # if sol_is_valid(l2) and str(l2) not in exclusions:
        #     voisins.append(l2)
        #     exclusions.add(str(l2))
        # l2 = make_n_permute(tuple_list, 2)
        # l2.sort()
        # if sol_is_valid(l2) and str(l2) not in exclusions:
        #     voisins.append(l2)
        #     exclusions.add(str(l2))
    # voisins+= permute_all_possibility(tuple_list)
    return voisins, exclusions

# %%
def update(A, Pa, obj_voisin, voisin, N_obj, exclusions):
    bad_memory=[]
    global_counter=0
    for i in range(len(A)):
        A_grand=0
        A_petit=0
        for k in range(N_obj):
            if A[i][0][k]>=obj_voisin[k]:
                A_grand+=1
            if A[i][0][k]<=obj_voisin[k]:
                A_petit+=1
        if A_petit == N_obj:
            break
        if A_grand == N_obj:
            bad_memory.append(i)
        global_counter+=1
    for indice in sorted(bad_memory, reverse=True):
        A.pop(indice)
    if global_counter == len(A)-len(bad_memory):
        Pa.append(voisin)
        A.append((obj_voisin, voisin))
        # exclusions.add(str(voisin))
    return A, Pa, exclusions

# %%
def load_solutions(filename):
    with open(f"solutions_pts_multi/{filename}", 'r') as r:
        N = int(r.readline())
        solutions = []
        for _ in range(N):
            lines = [eval(t) for t in r.readline().split('  ')]
            solutions.append(lines)
    return solutions

# %%
def write_exclusions(filename, exclusions):
    with open( "data.txt", 'w') as w:
        w.write(f"{len(exclusions)}\n")
        for pt in exclusions:
            w.write(f"{pt}\n")
def load_exclusions(filename):
    t=set()
    with open( "data.txt", 'r') as r:
        N = int(r.readline())
        for _ in range(N):
            t.add(r.readline().rstrip('\n'))
    return t

# %%
def initialise(objectifs, dim, N_obj,exclusions, init = 1 ,filename=''):
    if filename:
        P_temp = load_solutions(filename)
    else:
        P_temp = generate_best_single_obj(objectifs) + generate_identity_and_reverse(dim)
    vals = []
    for val in P_temp:
        vals += fast_random_permute(val, init, exclusions)[0]
    P_temp += vals
    A = []  # archive val obj
    Pa = []
    for p in P_temp:
        obj_voisin = fast_compute_objectifs(p, objectifs)
        if len(A) == 0:
            A.append((obj_voisin, p))
            Pa.append(p)
            p.sort()
            exclusions.add(str(p))
            pass
        A, Pa, exclusions = update(A, Pa, obj_voisin, p, N_obj, exclusions)
    P = Pa
    Pa = []
    return A, P, Pa, exclusions

# %%
def pareto_search(A, P, Pa, max_time, exclusions):
    start = time.time()
    stopper = 0
    while P:
        i_start = time.time()
        print(f"Iterations: {stopper + 1}")
        print(f"Lenght of A: {len(A)}")
        print(f"Lenght of P: {len(P)}")
        print(f"*** Excluded pts: {len(exclusions)} ***")
        for x in P:
            voisinage, exclusions = fast_random_permute(x, determine_voisin(P), exclusions)
            for voisin in voisinage:
                obj_voisin = fast_compute_objectifs(voisin, objectifs)
                A, Pa, exclusions = update(A, Pa, obj_voisin, voisin, N_obj, exclusions)
        i_end = time.time()
        print(f"Iteration time: {i_end - i_start}")
        print("----------------------------------")
        P = Pa
        Pa = []
        if (i_end - start) >= max_time:
            break
        stopper += 1
    end = time.time()
    run_time = end-start
    print(f"Total time: {run_time} seconds")
    print(f"Lenght of A: {len(A)}")
    return A, P, Pa, run_time, exclusions

# %%
def determine_voisin(P):
    if len(P)<10:
        return 2000
    elif len(P)<50:
        return 1000
    elif len(P)<100:
        return 500
    elif len(P)<500:
        return 250
    elif len(P)<1000:
        return 100
    elif len(P)<5000:
        return 5
    elif len(P)<10000:
        return 3
    else:
        return 2

# %%
N_obj = 4
lap = 15
# sols_filename = f'lap-{lap}/26_hv.txt'
sols_filename = f'lap-{lap}/_hv_LAP-{lap}.txt'
objectifs, dim, sols = load_datas(f'datas/LAP-{lap}.dat', N_obj, get_sol=False)

# %%
for _ in range(5):

    max_run_time=int(5*60)
    exclusions = set()
    exclusions = load_exclusions(f"exclusions_lap-{lap}")
    while max_run_time>0:
        print(f"==== Time remaining: {max_run_time}s ====")
        print(f"*** Excluded pts: {len(exclusions)} ***")
        A, P, Pa, exclusions = initialise(objectifs, dim, N_obj,exclusions,  init = 0,filename=sols_filename)
        A, P, Pa, run_time, exclusions =pareto_search(A, P, Pa, max_run_time, exclusions)
        write_solutions(lap, f"_hv_LAP-{lap}", A)
        max_run_time -=run_time
    write_exclusions(f'exclusion    s_lap-{lap}', exclusions)
# Out:
# ==== Time remaining: 300s ====
# *** Excluded pts: 0 ***
# Iterations: 1
# Lenght of A: 3526
# Lenght of P: 3526
# *** Excluded pts: 1 ***
# Iteration time: 15.046222925186157
# ----------------------------------
# Iterations: 2
# Lenght of A: 3529
# Lenght of P: 10
# *** Excluded pts: 86446 ***
# Iteration time: 2.670914888381958
# ----------------------------------
# Iterations: 3
# Lenght of A: 3527
# Lenght of P: 1
# *** Excluded pts: 118575 ***
# Iteration time: 0.612246036529541
# ----------------------------------
# Iterations: 4
# Lenght of A: 3527
# Lenght of P: 1
# *** Excluded pts: 124760 ***
# Iteration time: 0.5186941623687744
# ----------------------------------
# Total time: 18.848355054855347 seconds
# Lenght of A: 3527
# ==== Time remaining: 281.15164494514465s ====
# *** Excluded pts: 130922 ***
# Iterations: 1
# Lenght of A: 3527
# Lenght of P: 3527
# *** Excluded pts: 130922 ***
# Iteration time: 9.076124906539917
# ----------------------------------
# Iterations: 2
# Lenght of A: 3517
# Lenght of P: 3
# *** Excluded pts: 211137 ***
# Iteration time: 1.6834847927093506
# ----------------------------------
# Iterations: 3
# Lenght of A: 3520
# Lenght of P: 3
# *** Excluded pts: 229555 ***
# Iteration time: 1.5783605575561523
# ----------------------------------
# Iterations: 4
# Lenght of A: 3521
# Lenght of P: 1
# *** Excluded pts: 247856 ***
# Iteration time: 0.5257589817047119
# ----------------------------------
# Iterations: 5
# Lenght of A: 3523
# Lenght of P: 3
# *** Excluded pts: 254003 ***
# Iteration time: 1.5678093433380127
# ----------------------------------
# Iterations: 6
# Lenght of A: 3525
# Lenght of P: 3
# *** Excluded pts: 272362 ***
# Iteration time: 1.4788744449615479
# ----------------------------------
# Iterations: 7
# Lenght of A: 3526
# Lenght of P: 1
# *** Excluded pts: 290608 ***
# Iteration time: 0.5769979953765869
# ----------------------------------
# Total time: 16.48785400390625 seconds
# Lenght of A: 3526
# ==== Time remaining: 264.6637909412384s ====
# *** Excluded pts: 296760 ***
# Iterations: 1
# Lenght of A: 3526
# Lenght of P: 3526
# *** Excluded pts: 296760 ***
# Iteration time: 8.499862909317017
# ----------------------------------
# Iterations: 2
# Lenght of A: 3529
# Lenght of P: 7
# *** Excluded pts: 374420 ***
# Iteration time: 3.330807685852051
# ----------------------------------
# Iterations: 3
# Lenght of A: 3530
# Lenght of P: 3
# *** Excluded pts: 417375 ***
# Iteration time: 1.3757295608520508
# ----------------------------------
# Total time: 13.206581115722656 seconds
# Lenght of A: 3530
# ==== Time remaining: 251.45720982551575s ====
# *** Excluded pts: 435712 ***
# Iterations: 1
# Lenght of A: 3530
# Lenght of P: 3530
# *** Excluded pts: 435712 ***
# Iteration time: 8.877881050109863
# ----------------------------------
# Iterations: 2
# Lenght of A: 3527
# Lenght of P: 1
# *** Excluded pts: 511476 ***
# Iteration time: 0.4601614475250244
# ----------------------------------
# Total time: 9.338165283203125 seconds
# Lenght of A: 3527
# ==== Time remaining: 242.11904454231262s ====
# *** Excluded pts: 517572 ***
# Iterations: 1
# Lenght of A: 3527
# Lenght of P: 3527
# *** Excluded pts: 517572 ***
# Iteration time: 7.500773668289185
# ----------------------------------
# Iterations: 2
# Lenght of A: 3523
# Lenght of P: 2
# *** Excluded pts: 591580 ***
# Iteration time: 0.8861324787139893
# ----------------------------------
# Iterations: 3
# Lenght of A: 3524
# Lenght of P: 1
# *** Excluded pts: 603855 ***
# Iteration time: 0.4293532371520996
# ----------------------------------
# Iterations: 4
# Lenght of A: 3526
# Lenght of P: 2
# *** Excluded pts: 609960 ***
# Iteration time: 0.8800168037414551
# ----------------------------------
# Total time: 9.696528196334839 seconds
# Lenght of A: 3526
# ==== Time remaining: 232.42251634597778s ====
# *** Excluded pts: 622080 ***
# Iterations: 1
# Lenght of A: 3526
# Lenght of P: 3526
# *** Excluded pts: 622080 ***
# Iteration time: 7.271399259567261
# ----------------------------------
# Iterations: 2
# Lenght of A: 3523
# Lenght of P: 2
# *** Excluded pts: 694327 ***
# Iteration time: 0.9864706993103027
# ----------------------------------
# Total time: 8.257975339889526 seconds
# Lenght of A: 3523
# ==== Time remaining: 224.16454100608826s ====
# *** Excluded pts: 706562 ***
# Iterations: 1
# Lenght of A: 3523
# Lenght of P: 3523
# *** Excluded pts: 706562 ***
# Iteration time: 7.107022285461426
# ----------------------------------
# Iterations: 2
# Lenght of A: 3514
# Lenght of P: 3
# *** Excluded pts: 777342 ***
# Iteration time: 1.6009156703948975
# ----------------------------------
# Iterations: 3
# Lenght of A: 3515
# Lenght of P: 1
# *** Excluded pts: 795762 ***
# Iteration time: 0.4836561679840088
# ----------------------------------
# Total time: 9.19176173210144 seconds
# Lenght of A: 3515
# ==== Time remaining: 214.97277927398682s ====
# *** Excluded pts: 801924 ***
# Iterations: 1
# Lenght of A: 3515
# Lenght of P: 3515
# *** Excluded pts: 801924 ***
# Iteration time: 6.683443307876587
# ----------------------------------
# Total time: 6.683506011962891 seconds
# Lenght of A: 3507
# ==== Time remaining: 208.28927326202393s ====
# *** Excluded pts: 871338 ***
# Iterations: 1
# Lenght of A: 3507
# Lenght of P: 3507
# *** Excluded pts: 871338 ***
# Iteration time: 6.898348093032837
# ----------------------------------
# Iterations: 2
# Lenght of A: 3509
# Lenght of P: 3
# *** Excluded pts: 939436 ***
# Iteration time: 1.6640572547912598
# ----------------------------------
# Total time: 8.562516212463379 seconds
# Lenght of A: 3507
# ==== Time remaining: 199.72675704956055s ====
# *** Excluded pts: 957860 ***
# Iterations: 1
# Lenght of A: 3507
# Lenght of P: 3507
# *** Excluded pts: 957860 ***
# Iteration time: 5.78378701210022
# ----------------------------------
# Iterations: 2
# Lenght of A: 3506
# Lenght of P: 1
# *** Excluded pts: 1024590 ***
# Iteration time: 0.523690938949585
# ----------------------------------
# Total time: 6.3076255321502686 seconds
# Lenght of A: 3506
# ==== Time remaining: 193.41913151741028s ====
# *** Excluded pts: 1030753 ***
# Iterations: 1
# Lenght of A: 3506
# Lenght of P: 3506
# *** Excluded pts: 1030753 ***
# Iteration time: 6.281414031982422
# ----------------------------------
# Iterations: 2
# Lenght of A: 3507
# Lenght of P: 2
# *** Excluded pts: 1096582 ***
# Iteration time: 1.0068347454071045
# ----------------------------------
# Total time: 7.288361310958862 seconds
# Lenght of A: 3507
# ==== Time remaining: 186.13077020645142s ====
# *** Excluded pts: 1108838 ***
# Iterations: 1
# Lenght of A: 3507
# Lenght of P: 3507
# *** Excluded pts: 1108838 ***
# Iteration time: 5.947432041168213
# ----------------------------------
# Iterations: 2
# Lenght of A: 3509
# Lenght of P: 3
# *** Excluded pts: 1173659 ***
# Iteration time: 1.791977882385254
# ----------------------------------
# Total time: 7.740367889404297 seconds
# Lenght of A: 3509
# ==== Time remaining: 178.39040231704712s ====
# *** Excluded pts: 1192085 ***
# Iterations: 1
# Lenght of A: 3509
# Lenght of P: 3509
# *** Excluded pts: 1192085 ***
# Iteration time: 5.988424062728882
# ----------------------------------
# Total time: 5.988480091094971 seconds
# Lenght of A: 3507
# ==== Time remaining: 172.40192222595215s ====
# *** Excluded pts: 1256116 ***
# Iterations: 1
# Lenght of A: 3507
# Lenght of P: 3507
# *** Excluded pts: 1256116 ***
# Iteration time: 6.406463861465454
# ----------------------------------
# Iterations: 2
# Lenght of A: 3506
# Lenght of P: 3
# *** Excluded pts: 1319345 ***
# Iteration time: 1.5749990940093994
# ----------------------------------
# Iterations: 3
# Lenght of A: 3507
# Lenght of P: 1
# *** Excluded pts: 1337731 ***
# Iteration time: 0.4559023380279541
# ----------------------------------
# Total time: 8.437577724456787 seconds
# Lenght of A: 3507
# ==== Time remaining: 163.96434450149536s ====
# *** Excluded pts: 1343902 ***
# Iterations: 1
# Lenght of A: 3507
# Lenght of P: 3507
# *** Excluded pts: 1343902 ***
# Iteration time: 5.804463624954224
# ----------------------------------
# Iterations: 2
# Lenght of A: 3510
# Lenght of P: 3
# *** Excluded pts: 1406390 ***
# Iteration time: 1.5023508071899414
# ----------------------------------
# Total time: 7.30693507194519 seconds
# Lenght of A: 3509
# ==== Time remaining: 156.65740942955017s ====
# *** Excluded pts: 1424626 ***
# Iterations: 1
# Lenght of A: 3509
# Lenght of P: 3509
# *** Excluded pts: 1424626 ***
# Iteration time: 5.5455322265625
# ----------------------------------
# Iterations: 2
# Lenght of A: 3512
# Lenght of P: 4
# *** Excluded pts: 1486610 ***
# Iteration time: 2.191842555999756
# ----------------------------------
# Iterations: 3
# Lenght of A: 3514
# Lenght of P: 2
# *** Excluded pts: 1511046 ***
# Iteration time: 1.0711722373962402
# ----------------------------------
# Iterations: 4
# Lenght of A: 3513
# Lenght of P: 1
# *** Excluded pts: 1523214 ***
# Iteration time: 0.6314172744750977
# ----------------------------------
# Total time: 9.440191745758057 seconds
# Lenght of A: 3513
# ==== Time remaining: 147.21721768379211s ====
# *** Excluded pts: 1529217 ***
# Iterations: 1
# Lenght of A: 3513
# Lenght of P: 3513
# *** Excluded pts: 1529217 ***
# Iteration time: 5.409824371337891
# ----------------------------------
# Total time: 5.409875392913818 seconds
# Lenght of A: 3512
# ==== Time remaining: 141.8073422908783s ====
# *** Excluded pts: 1590561 ***
# Iterations: 1
# Lenght of A: 3512
# Lenght of P: 3512
# *** Excluded pts: 1590561 ***
# Iteration time: 5.720546245574951
# ----------------------------------
# Iterations: 2
# Lenght of A: 3513
# Lenght of P: 1
# *** Excluded pts: 1651277 ***
# Iteration time: 0.4527397155761719
# ----------------------------------
# Total time: 6.173493385314941 seconds
# Lenght of A: 3513
# ==== Time remaining: 135.63384890556335s ====
# *** Excluded pts: 1657360 ***
# Iterations: 1
# Lenght of A: 3513
# Lenght of P: 3513
# *** Excluded pts: 1657360 ***
# Iteration time: 5.34027361869812
# ----------------------------------
# Iterations: 2
# Lenght of A: 3513
# Lenght of P: 1
# *** Excluded pts: 1717571 ***
# Iteration time: 0.7135121822357178
# ----------------------------------
# Iterations: 3
# Lenght of A: 3514
# Lenght of P: 1
# *** Excluded pts: 1723662 ***
# Iteration time: 0.5176188945770264
# ----------------------------------
# Total time: 6.571671009063721 seconds
# Lenght of A: 3514
# ==== Time remaining: 129.06217789649963s ====
# *** Excluded pts: 1729801 ***
# Iterations: 1
# Lenght of A: 3514
# Lenght of P: 3514
# *** Excluded pts: 1729801 ***
# Iteration time: 4.904308080673218
# ----------------------------------
# Iterations: 2
# Lenght of A: 3515
# Lenght of P: 1
# *** Excluded pts: 1789586 ***
# Iteration time: 0.4564788341522217
# ----------------------------------
# Total time: 5.36089825630188 seconds
# Lenght of A: 3515
# ==== Time remaining: 123.70127964019775s ====
# *** Excluded pts: 1795715 ***
# Iterations: 1
# Lenght of A: 3515
# Lenght of P: 3515
# *** Excluded pts: 1795715 ***
# Iteration time: 5.162189960479736
# ----------------------------------
# Total time: 5.162266492843628 seconds
# Lenght of A: 3514
# ==== Time remaining: 118.53901314735413s ====
# *** Excluded pts: 1855006 ***
# Iterations: 1
# Lenght of A: 3514
# Lenght of P: 3514
# *** Excluded pts: 1855006 ***
# Iteration time: 5.37415885925293
# ----------------------------------
# Total time: 5.374230623245239 seconds
# Lenght of A: 3513
# ==== Time remaining: 113.16478252410889s ====
# *** Excluded pts: 1913913 ***
# Iterations: 1
# Lenght of A: 3513
# Lenght of P: 3513
# *** Excluded pts: 1913913 ***
# Iteration time: 5.155750274658203
# ----------------------------------
# Iterations: 2
# Lenght of A: 3514
# Lenght of P: 2
# *** Excluded pts: 1972514 ***
# Iteration time: 1.3515570163726807
# ----------------------------------
# Total time: 6.507424831390381 seconds
# Lenght of A: 3514
# ==== Time remaining: 106.6573576927185s ====
# *** Excluded pts: 1984741 ***
# Iterations: 1
# Lenght of A: 3514
# Lenght of P: 3514
# *** Excluded pts: 1984741 ***
# Iteration time: 4.917135953903198
# ----------------------------------
# Total time: 4.917187452316284 seconds
# Lenght of A: 3512
# ==== Time remaining: 101.74017024040222s ====
# *** Excluded pts: 2043000 ***
# Iterations: 1
# Lenght of A: 3512
# Lenght of P: 3512
# *** Excluded pts: 2043000 ***
# Iteration time: 4.873690366744995
# ----------------------------------
# Total time: 4.873752593994141 seconds
# Lenght of A: 3512
# ==== Time remaining: 96.86641764640808s ====
# *** Excluded pts: 2100664 ***
# Iterations: 1
# Lenght of A: 3512
# Lenght of P: 3512
# *** Excluded pts: 2100664 ***
# Iteration time: 4.533790349960327
# ----------------------------------
# Total time: 4.533861875534058 seconds
# Lenght of A: 3510
# ==== Time remaining: 92.33255577087402s ====
# *** Excluded pts: 2158182 ***
# Iterations: 1
# Lenght of A: 3510
# Lenght of P: 3510
# *** Excluded pts: 2158182 ***
# Iteration time: 4.912883996963501
# ----------------------------------
# Total time: 4.91297721862793 seconds
# Lenght of A: 3510
# ==== Time remaining: 87.4195785522461s ====
# *** Excluded pts: 2215530 ***
# Iterations: 1
# Lenght of A: 3510
# Lenght of P: 3510
# *** Excluded pts: 2215530 ***
# Iteration time: 4.8584818840026855
# ----------------------------------
# Iterations: 2
# Lenght of A: 3510
# Lenght of P: 1
# *** Excluded pts: 2272449 ***
# Iteration time: 0.5548696517944336
# ----------------------------------
# Iterations: 3
# Lenght of A: 3510
# Lenght of P: 1
# *** Excluded pts: 2278569 ***
# Iteration time: 0.5234041213989258
# ----------------------------------
# Total time: 5.936998605728149 seconds
# Lenght of A: 3510
# ==== Time remaining: 81.48257994651794s ====
# *** Excluded pts: 2284623 ***
# Iterations: 1
# Lenght of A: 3510
# Lenght of P: 3510
# *** Excluded pts: 2284623 ***
# Iteration time: 4.379501819610596
# ----------------------------------
# Iterations: 2
# Lenght of A: 3508
# Lenght of P: 1
# *** Excluded pts: 2341477 ***
# Iteration time: 0.4585278034210205
# ----------------------------------
# Iterations: 3
# Lenght of A: 3509
# Lenght of P: 1
# *** Excluded pts: 2347604 ***
# Iteration time: 0.4277026653289795
# ----------------------------------
# Total time: 5.265908718109131 seconds
# Lenght of A: 3509
# ==== Time remaining: 76.21667122840881s ====
# *** Excluded pts: 2353708 ***
# Iterations: 1
# Lenght of A: 3509
# Lenght of P: 3509
# *** Excluded pts: 2353708 ***
# Iteration time: 4.742443084716797
# ----------------------------------
# Total time: 4.742501497268677 seconds
# Lenght of A: 3509
# ==== Time remaining: 71.47416973114014s ====
# *** Excluded pts: 2410393 ***
# Iterations: 1
# Lenght of A: 3509
# Lenght of P: 3509
# *** Excluded pts: 2410393 ***
# Iteration time: 4.568342447280884
# ----------------------------------
# Total time: 4.5684003829956055 seconds
# Lenght of A: 3509
# ==== Time remaining: 66.90576934814453s ====
# *** Excluded pts: 2466672 ***
# Iterations: 1
# Lenght of A: 3509
# Lenght of P: 3509
# *** Excluded pts: 2466672 ***
# Iteration time: 4.476703405380249
# ----------------------------------
# Total time: 4.476752996444702 seconds
# Lenght of A: 3507
# ==== Time remaining: 62.42901635169983s ====
# *** Excluded pts: 2522884 ***
# Iterations: 1
# Lenght of A: 3507
# Lenght of P: 3507
# *** Excluded pts: 2522884 ***
# Iteration time: 4.6825034618377686
# ----------------------------------
# Iterations: 2
# Lenght of A: 3508
# Lenght of P: 1
# *** Excluded pts: 2578665 ***
# Iteration time: 0.58673095703125
# ----------------------------------
# Total time: 5.269417762756348 seconds
# Lenght of A: 3508
# ==== Time remaining: 57.15959858894348s ====
# *** Excluded pts: 2584737 ***
# Iterations: 1
# Lenght of A: 3508
# Lenght of P: 3508
# *** Excluded pts: 2584737 ***
# Iteration time: 4.500654458999634
# ----------------------------------
# Iterations: 2
# Lenght of A: 3509
# Lenght of P: 1
# *** Excluded pts: 2640346 ***
# Iteration time: 0.5171031951904297
# ----------------------------------
# Iterations: 3
# Lenght of A: 3509
# Lenght of P: 1
# *** Excluded pts: 2646494 ***
# Iteration time: 0.5603516101837158
# ----------------------------------
# Total time: 5.578328371047974 seconds
# Lenght of A: 3509
# ==== Time remaining: 51.58127021789551s ====
# *** Excluded pts: 2652613 ***
# Iterations: 1
# Lenght of A: 3509
# Lenght of P: 3509
# *** Excluded pts: 2652613 ***
# Iteration time: 4.460582733154297
# ----------------------------------
# Total time: 4.460630655288696 seconds
# Lenght of A: 3507
# ==== Time remaining: 47.12063956260681s ====
# *** Excluded pts: 2708258 ***
# Iterations: 1
# Lenght of A: 3507
# Lenght of P: 3507
# *** Excluded pts: 2708258 ***
# Iteration time: 4.533062219619751
# ----------------------------------
# Total time: 4.533157110214233 seconds
# Lenght of A: 3507
# ==== Time remaining: 42.58748245239258s ====
# *** Excluded pts: 2763750 ***
# Iterations: 1
# Lenght of A: 3507
# Lenght of P: 3507
# *** Excluded pts: 2763750 ***
# Iteration time: 4.527986526489258
# ----------------------------------
# Total time: 4.5280396938323975 seconds
# Lenght of A: 3507
# ==== Time remaining: 38.05944275856018s ====
# *** Excluded pts: 2819095 ***
# Iterations: 1
# Lenght of A: 3507
# Lenght of P: 3507
# *** Excluded pts: 2819095 ***
# Iteration time: 4.466673135757446
# ----------------------------------
# Total time: 4.466770172119141 seconds
# Lenght of A: 3506
# ==== Time remaining: 33.59267258644104s ====
# *** Excluded pts: 2874080 ***
# Iterations: 1
# Lenght of A: 3506
# Lenght of P: 3506
# *** Excluded pts: 2874080 ***
# Iteration time: 4.277071237564087
# ----------------------------------
# Iterations: 2
# Lenght of A: 3506
# Lenght of P: 1
# *** Excluded pts: 2929022 ***
# Iteration time: 0.4801294803619385
# ----------------------------------
# Total time: 4.757337331771851 seconds
# Lenght of A: 3506
# ==== Time remaining: 28.83533525466919s ====
# *** Excluded pts: 2935197 ***
# Iterations: 1
# Lenght of A: 3506
# Lenght of P: 3506
# *** Excluded pts: 2935197 ***
# Iteration time: 4.400925636291504
# ----------------------------------
# Iterations: 2
# Lenght of A: 3506
# Lenght of P: 1
# *** Excluded pts: 2990157 ***
# Iteration time: 0.5004956722259521
# ----------------------------------
# Iterations: 3
# Lenght of A: 3509
# Lenght of P: 3
# *** Excluded pts: 2996285 ***
# Iteration time: 1.6901021003723145
# ----------------------------------
# Total time: 6.591734886169434 seconds
# Lenght of A: 3509
# ==== Time remaining: 22.243600368499756s ====
# *** Excluded pts: 3014353 ***
# Iterations: 1
# Lenght of A: 3509
# Lenght of P: 3509
# *** Excluded pts: 3014353 ***
# Iteration time: 4.4473021030426025
# ----------------------------------
# Iterations: 2
# Lenght of A: 3510
# Lenght of P: 1
# *** Excluded pts: 3069171 ***
# Iteration time: 0.48258304595947266
# ----------------------------------
# Total time: 4.9300360679626465 seconds
# Lenght of A: 3510
# ==== Time remaining: 17.31356430053711s ====
# *** Excluded pts: 3075336 ***
# Iterations: 1
# Lenght of A: 3510
# Lenght of P: 3510
# *** Excluded pts: 3075336 ***
# Iteration time: 4.56563925743103
# ----------------------------------
# Iterations: 2
# Lenght of A: 3511
# Lenght of P: 1
# *** Excluded pts: 3130161 ***
# Iteration time: 0.539811372756958
# ----------------------------------
# Iterations: 3
# Lenght of A: 3512
# Lenght of P: 1
# *** Excluded pts: 3136277 ***
# Iteration time: 0.5809450149536133
# ----------------------------------
# Iterations: 4
# Lenght of A: 3513
# Lenght of P: 1
# *** Excluded pts: 3142389 ***
# Iteration time: 0.6580681800842285
# ----------------------------------
# Total time: 6.3449547290802 seconds
# Lenght of A: 3513
# ==== Time remaining: 10.96860957145691s ====
# *** Excluded pts: 3148480 ***
# Iterations: 1
# Lenght of A: 3513
# Lenght of P: 3513
# *** Excluded pts: 3148480 ***
# Iteration time: 4.000896453857422
# ----------------------------------
# Iterations: 2
# Lenght of A: 3514
# Lenght of P: 1
# *** Excluded pts: 3203194 ***
# Iteration time: 0.6296391487121582
# ----------------------------------
# Total time: 4.630671977996826 seconds
# Lenght of A: 3514
# ==== Time remaining: 6.337937593460083s ====
# *** Excluded pts: 3209302 ***
# Iterations: 1
# Lenght of A: 3514
# Lenght of P: 3514
# *** Excluded pts: 3209302 ***
# Iteration time: 4.4158594608306885
# ----------------------------------
# Total time: 4.4159111976623535 seconds
# Lenght of A: 3514
# ==== Time remaining: 1.9220263957977295s ====
# *** Excluded pts: 3263957 ***
# Iterations: 1
# Lenght of A: 3514
# Lenght of P: 3514
# *** Excluded pts: 3263957 ***
# Iteration time: 3.99722957611084
# ----------------------------------
# Total time: 3.997276782989502 seconds
# Lenght of A: 3514
# ==== Time remaining: 300s ====
# *** Excluded pts: 3318399 ***
# Iterations: 1
# Lenght of A: 3514
# Lenght of P: 3514
# *** Excluded pts: 3318399 ***
# Iteration time: 3.939668893814087
# ----------------------------------
# Total time: 3.939755439758301 seconds
# Lenght of A: 3510
# ==== Time remaining: 296.0602445602417s ====
# *** Excluded pts: 3372716 ***
# Iterations: 1
# Lenght of A: 3510
# Lenght of P: 3510
# *** Excluded pts: 3372716 ***
# Iteration time: 3.9261581897735596
# ----------------------------------
# Iterations: 2
# Lenght of A: 3511
# Lenght of P: 1
# *** Excluded pts: 3427062 ***
# Iteration time: 0.3904764652252197
# ----------------------------------
# Total time: 4.316774845123291 seconds
# Lenght of A: 3511
# ==== Time remaining: 291.7434697151184s ====
# *** Excluded pts: 3433159 ***
# Iterations: 1
# Lenght of A: 3511
# Lenght of P: 3511
# *** Excluded pts: 3433159 ***
# Iteration time: 3.9015231132507324
# ----------------------------------
# Iterations: 2
# Lenght of A: 3514
# Lenght of P: 3
# *** Excluded pts: 3487334 ***
# Iteration time: 1.5063550472259521
# ----------------------------------
# Iterations: 3
# Lenght of A: 3516
# Lenght of P: 2
# *** Excluded pts: 3505681 ***
# Iteration time: 0.9081284999847412
# ----------------------------------
# Total time: 6.316196918487549 seconds
# Lenght of A: 3516
# ==== Time remaining: 285.42727279663086s ====
# *** Excluded pts: 3517774 ***
# Iterations: 1
# Lenght of A: 3516
# Lenght of P: 3516
# *** Excluded pts: 3517774 ***
# Iteration time: 3.885378360748291
# ----------------------------------
# Iterations: 2
# Lenght of A: 3517
# Lenght of P: 1
# *** Excluded pts: 3571978 ***
# Iteration time: 0.579099178314209
# ----------------------------------
# Total time: 4.464582681655884 seconds
# Lenght of A: 3517
# ==== Time remaining: 280.962690114975s ====
# *** Excluded pts: 3578118 ***
# Iterations: 1
# Lenght of A: 3517
# Lenght of P: 3517
# *** Excluded pts: 3578118 ***
# Iteration time: 4.4529101848602295
# ----------------------------------
# Total time: 4.452962636947632 seconds
# Lenght of A: 3517
# ==== Time remaining: 276.50972747802734s ====
# *** Excluded pts: 3632293 ***
# Iterations: 1
# Lenght of A: 3517
# Lenght of P: 3517
# *** Excluded pts: 3632293 ***
# Iteration time: 3.9732160568237305
# ----------------------------------
# Total time: 3.9732658863067627 seconds
# Lenght of A: 3517
# ==== Time remaining: 272.5364615917206s ====
# *** Excluded pts: 3686445 ***
# Iterations: 1
# Lenght of A: 3517
# Lenght of P: 3517
# *** Excluded pts: 3686445 ***
# Iteration time: 4.063273191452026
# ----------------------------------
# Iterations: 2
# Lenght of A: 3518
# Lenght of P: 1
# *** Excluded pts: 3740534 ***
# Iteration time: 0.49080586433410645
# ----------------------------------
# Iterations: 3
# Lenght of A: 3519
# Lenght of P: 1
# *** Excluded pts: 3746626 ***
# Iteration time: 0.5015308856964111
# ----------------------------------
# Total time: 5.055851936340332 seconds
# Lenght of A: 3519
# ==== Time remaining: 267.48060965538025s ====
# *** Excluded pts: 3752750 ***
# Iterations: 1
# Lenght of A: 3519
# Lenght of P: 3519
# *** Excluded pts: 3752750 ***
# Iteration time: 4.344128608703613
# ----------------------------------
# Total time: 4.344183444976807 seconds
# Lenght of A: 3519
# ==== Time remaining: 263.13642621040344s ====
# *** Excluded pts: 3806728 ***
# Iterations: 1
# Lenght of A: 3519
# Lenght of P: 3519
# *** Excluded pts: 3806728 ***
# Iteration time: 4.365802049636841
# ----------------------------------
# Total time: 4.365855932235718 seconds
# Lenght of A: 3519
# ==== Time remaining: 258.7705702781677s ====
# *** Excluded pts: 3860711 ***
# Iterations: 1
# Lenght of A: 3519
# Lenght of P: 3519
# *** Excluded pts: 3860711 ***
# Iteration time: 4.054821252822876
# ----------------------------------
# Iterations: 2
# Lenght of A: 3520
# Lenght of P: 1
# *** Excluded pts: 3914507 ***
# Iteration time: 0.44571447372436523
# ----------------------------------
# Total time: 4.500639200210571 seconds
# Lenght of A: 3520
# ==== Time remaining: 254.26993107795715s ====
# *** Excluded pts: 3920615 ***
# Iterations: 1
# Lenght of A: 3520
# Lenght of P: 3520
# *** Excluded pts: 3920615 ***
# Iteration time: 4.278187036514282
# ----------------------------------
# Iterations: 2
# Lenght of A: 3520
# Lenght of P: 1
# *** Excluded pts: 3974460 ***
# Iteration time: 0.4817240238189697
# ----------------------------------
# Total time: 4.760039329528809 seconds
# Lenght of A: 3520
# ==== Time remaining: 249.50989174842834s ====
# *** Excluded pts: 3980515 ***
# Iterations: 1
# Lenght of A: 3520
# Lenght of P: 3520
# *** Excluded pts: 3980515 ***
# Iteration time: 3.855449914932251
# ----------------------------------
# Iterations: 2
# Lenght of A: 3522
# Lenght of P: 3
# *** Excluded pts: 4034209 ***
# Iteration time: 1.2938508987426758
# ----------------------------------
# Total time: 5.149429798126221 seconds
# Lenght of A: 3522
# ==== Time remaining: 244.36046195030212s ====
# *** Excluded pts: 4052525 ***
# Iterations: 1
# Lenght of A: 3522
# Lenght of P: 3522
# *** Excluded pts: 4052525 ***
# Iteration time: 4.047620534896851
# ----------------------------------
# Total time: 4.047716856002808 seconds
# Lenght of A: 3522
# ==== Time remaining: 240.31274509429932s ====
# *** Excluded pts: 4106424 ***
# Iterations: 1
# Lenght of A: 3522
# Lenght of P: 3522
# *** Excluded pts: 4106424 ***
# Iteration time: 3.9702301025390625
# ----------------------------------
# Iterations: 2
# Lenght of A: 3523
# Lenght of P: 1
# *** Excluded pts: 4160168 ***
# Iteration time: 0.3600311279296875
# ----------------------------------
# Iterations: 3
# Lenght of A: 3524
# Lenght of P: 1
# *** Excluded pts: 4166273 ***
# Iteration time: 0.38837361335754395
# ----------------------------------
# Total time: 4.718810796737671 seconds
# Lenght of A: 3524
# ==== Time remaining: 235.59393429756165s ====
# *** Excluded pts: 4172352 ***
# Iterations: 1
# Lenght of A: 3524
# Lenght of P: 3524
# *** Excluded pts: 4172352 ***
# Iteration time: 3.9792873859405518
# ----------------------------------
# Total time: 3.979337215423584 seconds
# Lenght of A: 3524
# ==== Time remaining: 231.61459708213806s ====
# *** Excluded pts: 4225955 ***
# Iterations: 1
# Lenght of A: 3524
# Lenght of P: 3524
# *** Excluded pts: 4225955 ***
# Iteration time: 3.9633047580718994
# ----------------------------------
# Total time: 3.9633727073669434 seconds
# Lenght of A: 3524
# ==== Time remaining: 227.65122437477112s ====
# *** Excluded pts: 4279568 ***
# Iterations: 1
# Lenght of A: 3524
# Lenght of P: 3524
# *** Excluded pts: 4279568 ***
# Iteration time: 3.884814739227295
# ----------------------------------
# Total time: 3.8848650455474854 seconds
# Lenght of A: 3523
# ==== Time remaining: 223.76635932922363s ====
# *** Excluded pts: 4333218 ***
# Iterations: 1
# Lenght of A: 3523
# Lenght of P: 3523
# *** Excluded pts: 4333218 ***
# Iteration time: 3.875577926635742
# ----------------------------------
# Iterations: 2
# Lenght of A: 3524
# Lenght of P: 1
# *** Excluded pts: 4386822 ***
# Iteration time: 0.6008672714233398
# ----------------------------------
# Total time: 4.476599216461182 seconds
# Lenght of A: 3524
# ==== Time remaining: 219.28976011276245s ====
# *** Excluded pts: 4392873 ***
# Iterations: 1
# Lenght of A: 3524
# Lenght of P: 3524
# *** Excluded pts: 4392873 ***
# Iteration time: 3.9456851482391357
# ----------------------------------
# Total time: 3.9457342624664307 seconds
# Lenght of A: 3524
# ==== Time remaining: 215.34402585029602s ====
# *** Excluded pts: 4446522 ***
# Iterations: 1
# Lenght of A: 3524
# Lenght of P: 3524
# *** Excluded pts: 4446522 ***
# Iteration time: 3.911682605743408
# ----------------------------------
# Iterations: 2
# Lenght of A: 3525
# Lenght of P: 1
# *** Excluded pts: 4500005 ***
# Iteration time: 0.46790432929992676
# ----------------------------------
# Total time: 4.379709720611572 seconds
# Lenght of A: 3525
# ==== Time remaining: 210.96431612968445s ====
# *** Excluded pts: 4506037 ***
# Iterations: 1
# Lenght of A: 3525
# Lenght of P: 3525
# *** Excluded pts: 4506037 ***
# Iteration time: 4.157925844192505
# ----------------------------------
# Total time: 4.157976150512695 seconds
# Lenght of A: 3525
# ==== Time remaining: 206.80633997917175s ====
# *** Excluded pts: 4559436 ***
# Iterations: 1
# Lenght of A: 3525
# Lenght of P: 3525
# *** Excluded pts: 4559436 ***
# Iteration time: 4.7370078563690186
# ----------------------------------
# Iterations: 2
# Lenght of A: 3526
# Lenght of P: 1
# *** Excluded pts: 4612904 ***
# Iteration time: 0.4607729911804199
# ----------------------------------
# Total time: 5.197929620742798 seconds
# Lenght of A: 3526
# ==== Time remaining: 201.60841035842896s ====
# *** Excluded pts: 4619037 ***
# Iterations: 1
# Lenght of A: 3526
# Lenght of P: 3526
# *** Excluded pts: 4619037 ***
# Iteration time: 4.093307256698608
# ----------------------------------
# Total time: 4.093379259109497 seconds
# Lenght of A: 3526
# ==== Time remaining: 197.51503109931946s ====
# *** Excluded pts: 4672352 ***
# Iterations: 1
# Lenght of A: 3526
# Lenght of P: 3526
# *** Excluded pts: 4672352 ***
# Iteration time: 3.9534618854522705
# ----------------------------------
# Total time: 3.9535202980041504 seconds
# Lenght of A: 3525
# ==== Time remaining: 193.5615108013153s ====
# *** Excluded pts: 4725825 ***
# Iterations: 1
# Lenght of A: 3525
# Lenght of P: 3525
# *** Excluded pts: 4725825 ***
# Iteration time: 3.8569772243499756
# ----------------------------------
# Iterations: 2
# Lenght of A: 3526
# Lenght of P: 1
# *** Excluded pts: 4779239 ***
# Iteration time: 0.4958186149597168
# ----------------------------------
# Total time: 4.352905511856079 seconds
# Lenght of A: 3526
# ==== Time remaining: 189.20860528945923s ====
# *** Excluded pts: 4785319 ***
# Iterations: 1
# Lenght of A: 3526
# Lenght of P: 3526
# *** Excluded pts: 4785319 ***
# Iteration time: 4.6161205768585205
# ----------------------------------
# Iterations: 2
# Lenght of A: 3527
# Lenght of P: 1
# *** Excluded pts: 4838645 ***
# Iteration time: 0.7596726417541504
# ----------------------------------
# Iterations: 3
# Lenght of A: 3528
# Lenght of P: 1
# *** Excluded pts: 4844722 ***
# Iteration time: 0.5111029148101807
# ----------------------------------
# Total time: 5.8871214389801025 seconds
# Lenght of A: 3528
# ==== Time remaining: 183.32148385047913s ====
# *** Excluded pts: 4850762 ***
# Iterations: 1
# Lenght of A: 3528
# Lenght of P: 3528
# *** Excluded pts: 4850762 ***
# Iteration time: 4.423687934875488
# ----------------------------------
# Iterations: 2
# Lenght of A: 3529
# Lenght of P: 1
# *** Excluded pts: 4904226 ***
# Iteration time: 0.529280424118042
# ----------------------------------
# Total time: 4.953100919723511 seconds
# Lenght of A: 3527
# ==== Time remaining: 178.36838293075562s ====
# *** Excluded pts: 4910347 ***
# Iterations: 1
# Lenght of A: 3527
# Lenght of P: 3527
# *** Excluded pts: 4910347 ***
# Iteration time: 3.986804723739624
# ----------------------------------
# Total time: 3.9868578910827637 seconds
# Lenght of A: 3527
# ==== Time remaining: 174.38152503967285s ====
# *** Excluded pts: 4963659 ***
# Iterations: 1
# Lenght of A: 3527
# Lenght of P: 3527
# *** Excluded pts: 4963659 ***
# Iteration time: 3.8605005741119385
# ----------------------------------
# Iterations: 2
# Lenght of A: 3529
# Lenght of P: 2
# *** Excluded pts: 5016838 ***
# Iteration time: 0.8790159225463867
# ----------------------------------
# Total time: 4.739620923995972 seconds
# Lenght of A: 3529
# ==== Time remaining: 169.64190411567688s ====
# *** Excluded pts: 5028907 ***
# Iterations: 1
# Lenght of A: 3529
# Lenght of P: 3529
# *** Excluded pts: 5028907 ***
# Iteration time: 4.130751848220825
# ----------------------------------
# Total time: 4.130833864212036 seconds
# Lenght of A: 3529
# ==== Time remaining: 165.51107025146484s ====
# *** Excluded pts: 5082153 ***
# Iterations: 1
# Lenght of A: 3529
# Lenght of P: 3529
# *** Excluded pts: 5082153 ***
# Iteration time: 3.8588478565216064
# ----------------------------------
# Total time: 3.858898162841797 seconds
# Lenght of A: 3529
# ==== Time remaining: 161.65217208862305s ====
# *** Excluded pts: 5135322 ***
# Iterations: 1
# Lenght of A: 3529
# Lenght of P: 3529
# *** Excluded pts: 5135322 ***
# Iteration time: 3.8416495323181152
# ----------------------------------
# Iterations: 2
# Lenght of A: 3530
# Lenght of P: 1
# *** Excluded pts: 5188468 ***
# Iteration time: 0.41556382179260254
# ----------------------------------
# Total time: 4.257322788238525 seconds
# Lenght of A: 3530
# ==== Time remaining: 157.39484930038452s ====
# *** Excluded pts: 5194569 ***
# Iterations: 1
# Lenght of A: 3530
# Lenght of P: 3530
# *** Excluded pts: 5194569 ***
# Iteration time: 3.815019369125366
# ----------------------------------
# Iterations: 2
# Lenght of A: 3531
# Lenght of P: 1
# *** Excluded pts: 5247755 ***
# Iteration time: 0.6617240905761719
# ----------------------------------
# Total time: 4.476850986480713 seconds
# Lenght of A: 3531
# ==== Time remaining: 152.9179983139038s ====
# *** Excluded pts: 5253853 ***
# Iterations: 1
# Lenght of A: 3531
# Lenght of P: 3531
# *** Excluded pts: 5253853 ***
# Iteration time: 3.823543071746826
# ----------------------------------
# Total time: 3.823594570159912 seconds
# Lenght of A: 3531
# ==== Time remaining: 149.0944037437439s ====
# *** Excluded pts: 5307005 ***
# Iterations: 1
# Lenght of A: 3531
# Lenght of P: 3531
# *** Excluded pts: 5307005 ***
# Iteration time: 3.955322265625
# ----------------------------------
# Total time: 3.9553983211517334 seconds
# Lenght of A: 3531
# ==== Time remaining: 145.13900542259216s ====
# *** Excluded pts: 5360029 ***
# Iterations: 1
# Lenght of A: 3531
# Lenght of P: 3531
# *** Excluded pts: 5360029 ***
# Iteration time: 4.0909106731414795
# ----------------------------------
# Iterations: 2
# Lenght of A: 3532
# Lenght of P: 1
# *** Excluded pts: 5413025 ***
# Iteration time: 0.7475526332855225
# ----------------------------------
# Total time: 4.838576078414917 seconds
# Lenght of A: 3532
# ==== Time remaining: 140.30042934417725s ====
# *** Excluded pts: 5419118 ***
# Iterations: 1
# Lenght of A: 3532
# Lenght of P: 3532
# *** Excluded pts: 5419118 ***
# Iteration time: 3.772395610809326
# ----------------------------------
# Total time: 3.7724435329437256 seconds
# Lenght of A: 3532
# ==== Time remaining: 136.52798581123352s ====
# *** Excluded pts: 5472157 ***
# Iterations: 1
# Lenght of A: 3532
# Lenght of P: 3532
# *** Excluded pts: 5472157 ***
# Iteration time: 3.7557642459869385
# ----------------------------------
# Total time: 3.755854368209839 seconds
# Lenght of A: 3532
# ==== Time remaining: 132.77213144302368s ====
# *** Excluded pts: 5525202 ***
# Iterations: 1
# Lenght of A: 3532
# Lenght of P: 3532
# *** Excluded pts: 5525202 ***
# Iteration time: 3.8792471885681152
# ----------------------------------
# Total time: 3.8793177604675293 seconds
# Lenght of A: 3532
# ==== Time remaining: 128.89281368255615s ====
# *** Excluded pts: 5578149 ***
# Iterations: 1
# Lenght of A: 3532
# Lenght of P: 3532
# *** Excluded pts: 5578149 ***
# Iteration time: 3.675309896469116
# ----------------------------------
# Total time: 3.6753592491149902 seconds
# Lenght of A: 3532
# ==== Time remaining: 125.21745443344116s ====
# *** Excluded pts: 5631039 ***
# Iterations: 1
# Lenght of A: 3532
# Lenght of P: 3532
# *** Excluded pts: 5631039 ***
# Iteration time: 3.8691461086273193
# ----------------------------------
# Total time: 3.8691983222961426 seconds
# Lenght of A: 3532
# ==== Time remaining: 121.34825611114502s ====
# *** Excluded pts: 5684085 ***
# Iterations: 1
# Lenght of A: 3532
# Lenght of P: 3532
# *** Excluded pts: 5684085 ***
# Iteration time: 3.945544481277466
# ----------------------------------
# Total time: 3.9455955028533936 seconds
# Lenght of A: 3532
# ==== Time remaining: 117.40266060829163s ====
# *** Excluded pts: 5736999 ***
# Iterations: 1
# Lenght of A: 3532
# Lenght of P: 3532
# *** Excluded pts: 5736999 ***
# Iteration time: 3.9743335247039795
# ----------------------------------
# Total time: 3.974400520324707 seconds
# Lenght of A: 3531
# ==== Time remaining: 113.42826008796692s ====
# *** Excluded pts: 5790078 ***
# Iterations: 1
# Lenght of A: 3531
# Lenght of P: 3531
# *** Excluded pts: 5790078 ***
# Iteration time: 3.885897636413574
# ----------------------------------
# Total time: 3.8859684467315674 seconds
# Lenght of A: 3531
# ==== Time remaining: 109.54229164123535s ====
# *** Excluded pts: 5843136 ***
# Iterations: 1
# Lenght of A: 3531
# Lenght of P: 3531
# *** Excluded pts: 5843136 ***
# Iteration time: 3.8112943172454834
# ----------------------------------
# Iterations: 2
# Lenght of A: 3532
# Lenght of P: 1
# *** Excluded pts: 5896003 ***
# Iteration time: 0.7517385482788086
# ----------------------------------
# Total time: 4.563216924667358 seconds
# Lenght of A: 3532
# ==== Time remaining: 104.979074716568s ====
# *** Excluded pts: 5902035 ***
# Iterations: 1
# Lenght of A: 3532
# Lenght of P: 3532
# *** Excluded pts: 5902035 ***
# Iteration time: 3.780773878097534
# ----------------------------------
# Total time: 3.7808339595794678 seconds
# Lenght of A: 3532
# ==== Time remaining: 101.19824075698853s ====
# *** Excluded pts: 5954956 ***
# Iterations: 1
# Lenght of A: 3532
# Lenght of P: 3532
# *** Excluded pts: 5954956 ***
# Iteration time: 3.7678394317626953
# ----------------------------------
# Iterations: 2
# Lenght of A: 3533
# Lenght of P: 1
# *** Excluded pts: 6007699 ***
# Iteration time: 0.38848161697387695
# ----------------------------------
# Total time: 4.1564781665802 seconds
# Lenght of A: 3533
# ==== Time remaining: 97.04176259040833s ====
# *** Excluded pts: 6013729 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6013729 ***
# Iteration time: 3.8058371543884277
# ----------------------------------
# Total time: 3.805905342102051 seconds
# Lenght of A: 3533
# ==== Time remaining: 93.23585724830627s ====
# *** Excluded pts: 6066512 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6066512 ***
# Iteration time: 3.683208465576172
# ----------------------------------
# Total time: 3.683262586593628 seconds
# Lenght of A: 3533
# ==== Time remaining: 89.55259466171265s ====
# *** Excluded pts: 6119362 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6119362 ***
# Iteration time: 4.1570305824279785
# ----------------------------------
# Total time: 4.157113790512085 seconds
# Lenght of A: 3533
# ==== Time remaining: 85.39548087120056s ====
# *** Excluded pts: 6172134 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6172134 ***
# Iteration time: 3.738507032394409
# ----------------------------------
# Total time: 3.7385571002960205 seconds
# Lenght of A: 3533
# ==== Time remaining: 81.65692377090454s ====
# *** Excluded pts: 6224705 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6224705 ***
# Iteration time: 3.8178701400756836
# ----------------------------------
# Total time: 3.817920207977295 seconds
# Lenght of A: 3532
# ==== Time remaining: 77.83900356292725s ====
# *** Excluded pts: 6277424 ***
# Iterations: 1
# Lenght of A: 3532
# Lenght of P: 3532
# *** Excluded pts: 6277424 ***
# Iteration time: 3.7256076335906982
# ----------------------------------
# Iterations: 2
# Lenght of A: 3533
# Lenght of P: 2
# *** Excluded pts: 6330232 ***
# Iteration time: 0.7707817554473877
# ----------------------------------
# Iterations: 3
# Lenght of A: 3535
# Lenght of P: 2
# *** Excluded pts: 6342365 ***
# Iteration time: 1.0497355461120605
# ----------------------------------
# Total time: 5.546296834945679 seconds
# Lenght of A: 3533
# ==== Time remaining: 72.29270672798157s ====
# *** Excluded pts: 6354479 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6354479 ***
# Iteration time: 3.9364986419677734
# ----------------------------------
# Total time: 3.936680316925049 seconds
# Lenght of A: 3533
# ==== Time remaining: 68.35602641105652s ====
# *** Excluded pts: 6407049 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6407049 ***
# Iteration time: 3.8851306438446045
# ----------------------------------
# Total time: 3.885185956954956 seconds
# Lenght of A: 3533
# ==== Time remaining: 64.47084045410156s ====
# *** Excluded pts: 6459720 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6459720 ***
# Iteration time: 3.9285919666290283
# ----------------------------------
# Total time: 3.9286723136901855 seconds
# Lenght of A: 3533
# ==== Time remaining: 60.54216814041138s ====
# *** Excluded pts: 6512422 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6512422 ***
# Iteration time: 4.138226270675659
# ----------------------------------
# Total time: 4.138299942016602 seconds
# Lenght of A: 3533
# ==== Time remaining: 56.403868198394775s ====
# *** Excluded pts: 6565008 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6565008 ***
# Iteration time: 4.339634656906128
# ----------------------------------
# Iterations: 2
# Lenght of A: 3534
# Lenght of P: 1
# *** Excluded pts: 6617558 ***
# Iteration time: 0.4467761516571045
# ----------------------------------
# Total time: 4.78652811050415 seconds
# Lenght of A: 3534
# ==== Time remaining: 51.617340087890625s ====
# *** Excluded pts: 6623679 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 6623679 ***
# Iteration time: 3.7667951583862305
# ----------------------------------
# Total time: 3.766883373260498 seconds
# Lenght of A: 3533
# ==== Time remaining: 47.85045671463013s ====
# *** Excluded pts: 6676249 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 6676249 ***
# Iteration time: 3.748302459716797
# ----------------------------------
# Iterations: 2
# Lenght of A: 3534
# Lenght of P: 1
# *** Excluded pts: 6728727 ***
# Iteration time: 0.4192845821380615
# ----------------------------------
# Total time: 4.167724132537842 seconds
# Lenght of A: 3534
# ==== Time remaining: 43.682732582092285s ====
# *** Excluded pts: 6734828 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 6734828 ***
# Iteration time: 3.8088314533233643
# ----------------------------------
# Total time: 3.8089094161987305 seconds
# Lenght of A: 3534
# ==== Time remaining: 39.873823165893555s ====
# *** Excluded pts: 6787339 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 6787339 ***
# Iteration time: 3.931159257888794
# ----------------------------------
# Total time: 3.931209087371826 seconds
# Lenght of A: 3534
# ==== Time remaining: 35.94261407852173s ====
# *** Excluded pts: 6839749 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 6839749 ***
# Iteration time: 3.758464813232422
# ----------------------------------
# Total time: 3.7585151195526123 seconds
# Lenght of A: 3534
# ==== Time remaining: 32.184098958969116s ====
# *** Excluded pts: 6892127 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 6892127 ***
# Iteration time: 3.868112087249756
# ----------------------------------
# Total time: 3.868196487426758 seconds
# Lenght of A: 3534
# ==== Time remaining: 28.31590247154236s ====
# *** Excluded pts: 6944458 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 6944458 ***
# Iteration time: 3.9717934131622314
# ----------------------------------
# Total time: 3.9718422889709473 seconds
# Lenght of A: 3534
# ==== Time remaining: 24.34406018257141s ====
# *** Excluded pts: 6996858 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 6996858 ***
# Iteration time: 3.7421679496765137
# ----------------------------------
# Total time: 3.7422678470611572 seconds
# Lenght of A: 3534
# ==== Time remaining: 20.601792335510254s ====
# *** Excluded pts: 7049188 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7049188 ***
# Iteration time: 3.85677170753479
# ----------------------------------
# Total time: 3.856842041015625 seconds
# Lenght of A: 3534
# ==== Time remaining: 16.74495029449463s ====
# *** Excluded pts: 7101539 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7101539 ***
# Iteration time: 3.6821067333221436
# ----------------------------------
# Total time: 3.6821882724761963 seconds
# Lenght of A: 3534
# ==== Time remaining: 13.062762022018433s ====
# *** Excluded pts: 7153715 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7153715 ***
# Iteration time: 3.6677188873291016
# ----------------------------------
# Iterations: 2
# Lenght of A: 3535
# Lenght of P: 1
# *** Excluded pts: 7206126 ***
# Iteration time: 0.4217667579650879
# ----------------------------------
# Total time: 4.089589357376099 seconds
# Lenght of A: 3535
# ==== Time remaining: 8.973172664642334s ====
# *** Excluded pts: 7212235 ***
# Iterations: 1
# Lenght of A: 3535
# Lenght of P: 3535
# *** Excluded pts: 7212235 ***
# Iteration time: 3.7621686458587646
# ----------------------------------
# Total time: 3.7622182369232178 seconds
# Lenght of A: 3535
# ==== Time remaining: 5.210954427719116s ====
# *** Excluded pts: 7264474 ***
# Iterations: 1
# Lenght of A: 3535
# Lenght of P: 3535
# *** Excluded pts: 7264474 ***
# Iteration time: 3.7540528774261475
# ----------------------------------
# Total time: 3.754105567932129 seconds
# Lenght of A: 3535
# ==== Time remaining: 1.4568488597869873s ====
# *** Excluded pts: 7316753 ***
# Iterations: 1
# Lenght of A: 3535
# Lenght of P: 3535
# *** Excluded pts: 7316753 ***
# Iteration time: 3.729682207107544
# ----------------------------------
# Total time: 3.729729652404785 seconds
# Lenght of A: 3534
# ==== Time remaining: 300s ====
# *** Excluded pts: 7369088 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7369088 ***
# Iteration time: 3.7565696239471436
# ----------------------------------
# Total time: 3.7566206455230713 seconds
# Lenght of A: 3534
# ==== Time remaining: 296.24337935447693s ====
# *** Excluded pts: 7421245 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7421245 ***
# Iteration time: 3.7307701110839844
# ----------------------------------
# Iterations: 2
# Lenght of A: 3536
# Lenght of P: 2
# *** Excluded pts: 7473450 ***
# Iteration time: 1.1706840991973877
# ----------------------------------
# Total time: 4.9015655517578125 seconds
# Lenght of A: 3535
# ==== Time remaining: 291.3418138027191s ====
# *** Excluded pts: 7485559 ***
# Iterations: 1
# Lenght of A: 3535
# Lenght of P: 3535
# *** Excluded pts: 7485559 ***
# Iteration time: 3.679156541824341
# ----------------------------------
# Total time: 3.679206371307373 seconds
# Lenght of A: 3535
# ==== Time remaining: 287.66260743141174s ====
# *** Excluded pts: 7537756 ***
# Iterations: 1
# Lenght of A: 3535
# Lenght of P: 3535
# *** Excluded pts: 7537756 ***
# Iteration time: 3.6951634883880615
# ----------------------------------
# Total time: 3.695216178894043 seconds
# Lenght of A: 3533
# ==== Time remaining: 283.9673912525177s ====
# *** Excluded pts: 7589891 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 7589891 ***
# Iteration time: 3.6534481048583984
# ----------------------------------
# Iterations: 2
# Lenght of A: 3534
# Lenght of P: 1
# *** Excluded pts: 7641808 ***
# Iteration time: 0.40622425079345703
# ----------------------------------
# Total time: 4.059801816940308 seconds
# Lenght of A: 3534
# ==== Time remaining: 279.9075894355774s ====
# *** Excluded pts: 7647917 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7647917 ***
# Iteration time: 3.817126750946045
# ----------------------------------
# Total time: 3.8171794414520264 seconds
# Lenght of A: 3534
# ==== Time remaining: 276.09040999412537s ====
# *** Excluded pts: 7699917 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7699917 ***
# Iteration time: 3.743638515472412
# ----------------------------------
# Total time: 3.743717670440674 seconds
# Lenght of A: 3534
# ==== Time remaining: 272.3466923236847s ====
# *** Excluded pts: 7751900 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7751900 ***
# Iteration time: 3.856839656829834
# ----------------------------------
# Total time: 3.8569047451019287 seconds
# Lenght of A: 3534
# ==== Time remaining: 268.48978757858276s ====
# *** Excluded pts: 7803883 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7803883 ***
# Iteration time: 4.01364803314209
# ----------------------------------
# Total time: 4.013697385787964 seconds
# Lenght of A: 3534
# ==== Time remaining: 264.4760901927948s ====
# *** Excluded pts: 7856002 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7856002 ***
# Iteration time: 4.096224069595337
# ----------------------------------
# Total time: 4.0962793827056885 seconds
# Lenght of A: 3534
# ==== Time remaining: 260.3798108100891s ====
# *** Excluded pts: 7907958 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7907958 ***
# Iteration time: 4.763113021850586
# ----------------------------------
# Total time: 4.763227224349976 seconds
# Lenght of A: 3534
# ==== Time remaining: 255.61658358573914s ====
# *** Excluded pts: 7959902 ***
# Iterations: 1
# Lenght of A: 3534
# Lenght of P: 3534
# *** Excluded pts: 7959902 ***
# Iteration time: 3.836155414581299
# ----------------------------------
# Total time: 3.8362083435058594 seconds
# Lenght of A: 3533
# ==== Time remaining: 251.78037524223328s ====
# *** Excluded pts: 8011852 ***
# Iterations: 1
# Lenght of A: 3533
# Lenght of P: 3533
# *** Excluded pts: 8011852 ***
# Iteration time: 3.7180497646331787
# ----------------------------------
# ...
# *** Excluded pts: 16581472 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 16581472 ***
# Iteration time: 3.3165223598480225
# ----------------------------------
# Total time: 3.3165719509124756 seconds
# Lenght of A: 3553
# ==== Time remaining: 215.89936089515686s ====
# *** Excluded pts: 16631000 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 16631000 ***
# Iteration time: 3.2802796363830566
# ----------------------------------
# Total time: 3.2803313732147217 seconds
# Lenght of A: 3553
# ==== Time remaining: 212.61902952194214s ====
# *** Excluded pts: 16680331 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 16680331 ***
# Iteration time: 3.2709431648254395
# ----------------------------------
# Total time: 3.270996570587158 seconds
# Lenght of A: 3553
# ==== Time remaining: 209.34803295135498s ====
# *** Excluded pts: 16729823 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 16729823 ***
# Iteration time: 3.3100805282592773
# ----------------------------------
# Total time: 3.310145139694214 seconds
# Lenght of A: 3553
# ==== Time remaining: 206.03788781166077s ====
# *** Excluded pts: 16779178 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 16779178 ***
# Iteration time: 3.2694404125213623
# ----------------------------------
# Total time: 3.269488573074341 seconds
# Lenght of A: 3553
# ==== Time remaining: 202.76839923858643s ====
# *** Excluded pts: 16828601 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 16828601 ***
# Iteration time: 3.6056301593780518
# ----------------------------------
# Total time: 3.605696439743042 seconds
# Lenght of A: 3553
# ==== Time remaining: 199.16270279884338s ====
# *** Excluded pts: 16878203 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 16878203 ***
# Iteration time: 3.480943441390991
# ----------------------------------
# Total time: 3.4810097217559814 seconds
# Lenght of A: 3553
# ==== Time remaining: 195.6816930770874s ====
# *** Excluded pts: 16927719 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 16927719 ***
# Iteration time: 4.1077561378479
# ----------------------------------
# Total time: 4.107802867889404 seconds
# Lenght of A: 3553
# ==== Time remaining: 191.573890209198s ====
# *** Excluded pts: 16977184 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 16977184 ***
# Iteration time: 4.214220285415649
# ----------------------------------
# Total time: 4.214291334152222 seconds
# Lenght of A: 3553
# ==== Time remaining: 187.35959887504578s ====
# *** Excluded pts: 17026504 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 17026504 ***
# Iteration time: 4.209510087966919
# ----------------------------------
# Total time: 4.209627866744995 seconds
# Lenght of A: 3553
# ==== Time remaining: 183.14997100830078s ====
# *** Excluded pts: 17075924 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 17075924 ***
# Iteration time: 4.057915925979614
# ----------------------------------
# Total time: 4.058002948760986 seconds
# Lenght of A: 3553
# ==== Time remaining: 179.0919680595398s ====
# *** Excluded pts: 17125320 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 17125320 ***
# Iteration time: 4.062475204467773
# ----------------------------------
# Total time: 4.062565803527832 seconds
# Lenght of A: 3553
# ==== Time remaining: 175.02940225601196s ====
# *** Excluded pts: 17174606 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 17174606 ***
# Iteration time: 4.005898714065552
# ----------------------------------
# Total time: 4.005953550338745 seconds
# Lenght of A: 3553
# ==== Time remaining: 171.02344870567322s ====
# *** Excluded pts: 17223878 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 17223878 ***
# Iteration time: 4.25805926322937
# ----------------------------------
# Total time: 4.258138179779053 seconds
# Lenght of A: 3553
# ==== Time remaining: 166.76531052589417s ====
# *** Excluded pts: 17273217 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 17273217 ***
# Iteration time: 3.5887537002563477
# ----------------------------------
# Total time: 3.5888025760650635 seconds
# Lenght of A: 3553
# ==== Time remaining: 163.1765079498291s ====
# *** Excluded pts: 17322515 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 17322515 ***
# Iteration time: 4.405474901199341
# ----------------------------------
# Total time: 4.405592441558838 seconds
# Lenght of A: 3553
# ==== Time remaining: 158.77091550827026s ====
# *** Excluded pts: 17371742 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 17371742 ***
# Iteration time: 3.8672046661376953
# ----------------------------------
# Iterations: 2
# Lenght of A: 3554
# Lenght of P: 1
# *** Excluded pts: 17421033 ***
# Iteration time: 1.4257161617279053
# ----------------------------------
# Total time: 5.293069839477539 seconds
# Lenght of A: 3554
# ==== Time remaining: 153.47784566879272s ====
# *** Excluded pts: 17427119 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17427119 ***
# Iteration time: 3.8822250366210938
# ----------------------------------
# Total time: 3.882378101348877 seconds
# Lenght of A: 3554
# ==== Time remaining: 149.59546756744385s ====
# *** Excluded pts: 17476502 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17476502 ***
# Iteration time: 4.002595663070679
# ----------------------------------
# Total time: 4.002666473388672 seconds
# Lenght of A: 3554
# ==== Time remaining: 145.59280109405518s ====
# *** Excluded pts: 17525777 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17525777 ***
# Iteration time: 3.8838415145874023
# ----------------------------------
# Total time: 3.8841023445129395 seconds
# Lenght of A: 3554
# ==== Time remaining: 141.70869874954224s ====
# *** Excluded pts: 17575194 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17575194 ***
# Iteration time: 3.861611843109131
# ----------------------------------
# Total time: 3.8616623878479004 seconds
# Lenght of A: 3554
# ==== Time remaining: 137.84703636169434s ====
# *** Excluded pts: 17624500 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17624500 ***
# Iteration time: 3.951226234436035
# ----------------------------------
# Total time: 3.951287269592285 seconds
# Lenght of A: 3554
# ==== Time remaining: 133.89574909210205s ====
# *** Excluded pts: 17673749 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17673749 ***
# Iteration time: 3.9073030948638916
# ----------------------------------
# Total time: 3.907358407974243 seconds
# Lenght of A: 3554
# ==== Time remaining: 129.9883906841278s ====
# *** Excluded pts: 17723048 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17723048 ***
# Iteration time: 3.992192029953003
# ----------------------------------
# Total time: 3.9922475814819336 seconds
# Lenght of A: 3554
# ==== Time remaining: 125.99614310264587s ====
# *** Excluded pts: 17772251 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17772251 ***
# Iteration time: 3.9103171825408936
# ----------------------------------
# Total time: 3.9103755950927734 seconds
# Lenght of A: 3554
# ==== Time remaining: 122.0857675075531s ====
# *** Excluded pts: 17821517 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17821517 ***
# Iteration time: 3.957334280014038
# ----------------------------------
# Total time: 3.9573872089385986 seconds
# Lenght of A: 3554
# ==== Time remaining: 118.1283802986145s ====
# *** Excluded pts: 17870739 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17870739 ***
# Iteration time: 3.970564603805542
# ----------------------------------
# Total time: 3.9707069396972656 seconds
# Lenght of A: 3554
# ==== Time remaining: 114.15767335891724s ====
# *** Excluded pts: 17920119 ***
# Iterations: 1
# Lenght of A: 3554
# Lenght of P: 3554
# *** Excluded pts: 17920119 ***
# Iteration time: 4.494313478469849
# ----------------------------------
# Total time: 4.494429349899292 seconds
# Lenght of A: 3553
# ==== Time remaining: 109.66324400901794s ====
# *** Excluded pts: 17969450 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 17969450 ***
# Iteration time: 4.004606008529663
# ----------------------------------
# Total time: 4.0047690868377686 seconds
# Lenght of A: 3553
# ==== Time remaining: 105.65847492218018s ====
# *** Excluded pts: 18018693 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18018693 ***
# Iteration time: 4.0336854457855225
# ----------------------------------
# Total time: 4.0337653160095215 seconds
# Lenght of A: 3553
# ==== Time remaining: 101.62470960617065s ====
# *** Excluded pts: 18067828 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18067828 ***
# Iteration time: 4.024943113327026
# ----------------------------------
# Total time: 4.025010824203491 seconds
# Lenght of A: 3553
# ==== Time remaining: 97.59969878196716s ====
# *** Excluded pts: 18117072 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18117072 ***
# Iteration time: 3.9513514041900635
# ----------------------------------
# Total time: 3.951418399810791 seconds
# Lenght of A: 3553
# ==== Time remaining: 93.64828038215637s ====
# *** Excluded pts: 18166140 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18166140 ***
# Iteration time: 4.396514415740967
# ----------------------------------
# Total time: 4.396670341491699 seconds
# Lenght of A: 3553
# ==== Time remaining: 89.25161004066467s ====
# *** Excluded pts: 18215280 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18215280 ***
# Iteration time: 3.9755890369415283
# ----------------------------------
# Total time: 3.9757041931152344 seconds
# Lenght of A: 3553
# ==== Time remaining: 85.27590584754944s ====
# *** Excluded pts: 18264498 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18264498 ***
# Iteration time: 4.086307525634766
# ----------------------------------
# Total time: 4.086376190185547 seconds
# Lenght of A: 3553
# ==== Time remaining: 81.18952965736389s ====
# *** Excluded pts: 18313582 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18313582 ***
# Iteration time: 4.001570701599121
# ----------------------------------
# Total time: 4.001636505126953 seconds
# Lenght of A: 3553
# ==== Time remaining: 77.18789315223694s ====
# *** Excluded pts: 18362642 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18362642 ***
# Iteration time: 3.9795193672180176
# ----------------------------------
# Total time: 3.9796178340911865 seconds
# Lenght of A: 3553
# ==== Time remaining: 73.20827531814575s ====
# *** Excluded pts: 18411825 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18411825 ***
# Iteration time: 4.298168182373047
# ----------------------------------
# Total time: 4.298228979110718 seconds
# Lenght of A: 3553
# ==== Time remaining: 68.91004633903503s ====
# *** Excluded pts: 18460928 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18460928 ***
# Iteration time: 3.8927297592163086
# ----------------------------------
# Total time: 3.8928425312042236 seconds
# Lenght of A: 3553
# ==== Time remaining: 65.01720380783081s ====
# *** Excluded pts: 18510038 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18510038 ***
# Iteration time: 3.9880897998809814
# ----------------------------------
# Total time: 3.988262176513672 seconds
# Lenght of A: 3553
# ==== Time remaining: 61.02894163131714s ====
# *** Excluded pts: 18559055 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18559055 ***
# Iteration time: 4.062647342681885
# ----------------------------------
# Total time: 4.062762498855591 seconds
# Lenght of A: 3553
# ==== Time remaining: 56.96617913246155s ====
# *** Excluded pts: 18608241 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18608241 ***
# Iteration time: 4.055634498596191
# ----------------------------------
# Total time: 4.055694341659546 seconds
# Lenght of A: 3553
# ==== Time remaining: 52.910484790802s ====
# *** Excluded pts: 18657270 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18657270 ***
# Iteration time: 3.9922823905944824
# ----------------------------------
# Total time: 3.9923815727233887 seconds
# Lenght of A: 3553
# ==== Time remaining: 48.91810321807861s ====
# *** Excluded pts: 18706351 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18706351 ***
# Iteration time: 3.9822890758514404
# ----------------------------------
# Total time: 3.9823739528656006 seconds
# Lenght of A: 3553
# ==== Time remaining: 44.93572926521301s ====
# *** Excluded pts: 18755420 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18755420 ***
# Iteration time: 4.358825922012329
# ----------------------------------
# Total time: 4.358879327774048 seconds
# Lenght of A: 3553
# ==== Time remaining: 40.576849937438965s ====
# *** Excluded pts: 18804489 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18804489 ***
# Iteration time: 3.900926113128662
# ----------------------------------
# Total time: 3.9010071754455566 seconds
# Lenght of A: 3553
# ==== Time remaining: 36.67584276199341s ====
# *** Excluded pts: 18853447 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18853447 ***
# Iteration time: 3.9710898399353027
# ----------------------------------
# Total time: 3.97116756439209 seconds
# Lenght of A: 3553
# ==== Time remaining: 32.70467519760132s ====
# *** Excluded pts: 18902366 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18902366 ***
# Iteration time: 4.090831995010376
# ----------------------------------
# Total time: 4.090891361236572 seconds
# Lenght of A: 3553
# ==== Time remaining: 28.613783836364746s ====
# *** Excluded pts: 18951337 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 18951337 ***
# Iteration time: 3.85457444190979
# ----------------------------------
# Total time: 3.8547019958496094 seconds
# Lenght of A: 3553
# ==== Time remaining: 24.759081840515137s ====
# *** Excluded pts: 19000121 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 19000121 ***
# Iteration time: 3.897631883621216
# ----------------------------------
# Total time: 3.897778034210205 seconds
# Lenght of A: 3553
# ==== Time remaining: 20.86130380630493s ====
# *** Excluded pts: 19048796 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 19048796 ***
# Iteration time: 3.913422107696533
# ----------------------------------
# Total time: 3.9135491847991943 seconds
# Lenght of A: 3553
# ==== Time remaining: 16.947754621505737s ====
# *** Excluded pts: 19097772 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 19097772 ***
# Iteration time: 3.8980841636657715
# ----------------------------------
# Total time: 3.8981409072875977 seconds
# Lenght of A: 3553
# ==== Time remaining: 13.04961371421814s ====
# *** Excluded pts: 19146753 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 19146753 ***
# Iteration time: 3.837245464324951
# ----------------------------------
# Total time: 3.8373496532440186 seconds
# Lenght of A: 3553
# ==== Time remaining: 9.212264060974121s ====
# *** Excluded pts: 19195706 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 19195706 ***
# Iteration time: 3.803523540496826
# ----------------------------------
# Total time: 3.803574800491333 seconds
# Lenght of A: 3553
# ==== Time remaining: 5.408689260482788s ====
# *** Excluded pts: 19244609 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 19244609 ***
# Iteration time: 4.342936754226685
# ----------------------------------
# Total time: 4.3429951667785645 seconds
# Lenght of A: 3553
# ==== Time remaining: 1.0656940937042236s ====
# *** Excluded pts: 19293615 ***
# Iterations: 1
# Lenght of A: 3553
# Lenght of P: 3553
# *** Excluded pts: 19293615 ***
# Iteration time: 4.01387095451355
# ----------------------------------
# Total time: 4.0140156745910645 seconds
# Lenght of A: 3553

# %%
# pareto = []
# for a in A:
#     pareto.append(np.array(a[0]))
# pareto = np.array(pareto)
# ref_15 = np.array([112, 206, 247, 418])
# ref_20 = np.array([137, 304, 414, 531])
# ref_30 = np.array([211, 381, 581, 835])
# if lap == 15:
#     ref_point = ref_15
# elif lap == 20:
#     ref_point = ref_20
# elif lap == 30:
#     ref_point = ref_30
# else:
#     pt = 900
#     ref_point = np.array([pt, pt, pt, pt])
#
# ind = HV(ref_point=ref_point)
# hv = ind(pareto)
# print("HV", hv)
# print(f"Norm: {hv / (np.prod(ref_point))}")

# %%
# write_solutions(lap, f"{int(round(hv / (np.prod(ref_point)) * 100, 0))}_hv_LAP-{lap}", A)
# write_solutions(lap, f"_hv_LAP-{lap}", A)

# %%
write_exclusions(f'exclusions_lap-{lap}', set())
